# %%
import numpy as np
import math, json
from rdp import rdp
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML
import tqdm.notebook as tq
import pickle
from collections import defaultdict
import cairosvg
from PIL import Image,ImageDraw
import glob
import os 
import re
import svgwrite
# Out:
# In /home/esp1/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/esp1/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/esp1/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/esp1/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/esp1/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/esp1/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/esp1/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/esp1/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
def get_bounds(data):
    minx, miny = 600, 600  
    maxx, maxy = 0, 0
    
    for i, (x, y, z) in enumerate(data): 
        if minx > x:
            minx = x
        if miny > y:
            miny = y 

        if maxx < x:
            maxx = x
        if maxy < y:
            maxy = y 
    return minx, maxx, miny, maxy

# %%
def convert_3d(drawing, return_flag = False, threshold=10):
    out = []
    corrupted = False
    for item in drawing:
        char = list(item.keys())[0]
        stroke = item[char]
        if len(stroke) == 1:
            x, y = stroke[0]
            out.append([x, y, 0])
            out.append([x+5, y+5, 1])
            continue
        segment = []
        for i, point in enumerate(stroke):
            x, y = point 
            if i == len(stroke) - 1:
                segment.append([x, y, 1])
            else:
                segment.append([x, y, 0])
        
        start = 0 
        for i, point in enumerate(segment):
            if i < len(segment) -1:
                x, y, _ = point
                next_x, next_y, _ = segment[i+1]
                if any((
                    abs(x-next_x)>threshold,
                    abs(y-next_y>threshold),
                )):
                    corrupted=True
                    start = i +1
        
        out += segment[start:]
    if return_flag:
        return out, corrupted
    return out

# %%
def make_square(im, min_size=256, fill_color=(255, 255, 255)):
    x, y = im.size
    size = max(min_size, x, y)
    new_im = Image.new('RGBA', (size, size), fill_color)
    new_im.paste(im, (int((size - x) / 2), int((size - y) / 2)))
    return new_im

# %%
def draw_strokes(data, factor=1, svg_filename = 'tmp/sample.svg', stroke_width = 3, square = False, return_res = False):
    min_x, max_x, min_y, max_y = get_bounds(data)
    dims = (50 + max_x - min_x, 50 + max_y - min_y)
    dwg = svgwrite.Drawing(svg_filename, size = dims)
    dwg.add(dwg.rect(insert=(0, 0), size=dims,fill='white'))
    lift_pen = 1
    abs_x = 25 - min_x 
    abs_y = 25 - min_y
    p = "M%s,%s " % (abs_x, abs_y)
    command = "M"
    for i in range(len(data)):
        if (lift_pen == 1):
            command = "M"
        elif (command != "L"):
            command = "L"
        else:
            command = ""
        x = float(data[i][0]) - min_x
        y = float(data[i][1]) - min_y
        lift_pen = data[i][2]
        p += command+str(x)+" "+str(y)+" "
    the_color = "black"
    
    dwg.add(dwg.path(p).stroke(the_color,stroke_width).fill("none"))
    dwg.save()
    cairosvg.svg2png(url="tmp/sample.svg", write_to="tmp/sample.png")
    img = Image.open('tmp/sample.png')
    if square:
        img = make_square(img)
    if return_res:
        return img, dims 
    else:
        return img

# %%
npy_files = glob.glob('server/data/*')
file = np.random.choice(npy_files)

# %%
drawing = json.load(open(file))
data1, flag = convert_3d(drawing, return_flag=True, threshold=50)
plt.imshow(draw_strokes(data1, stroke_width = 5))
plt.show()

# %%
target_file_name + '_'+ ctr +'.json' in [f.split('/')[-1] for f in glob.glob('dataset/**/**.json')]
# Out:
# False

# %%
# !rm -r dataset

# %%
import shutil 
import glob 
from random import  shuffle
os.makedirs('dataset', exist_ok = True)
os.makedirs('dataset/train', exist_ok = True)
os.makedirs('dataset/valid', exist_ok = True)
os.makedirs('dataset/test', exist_ok = True)

files = glob.glob('server/data/*') + glob.glob('server/larger_data/*')
shuffle(files)

for i, file in enumerate(files):
    file_name = file.split('/')[-1][:-5]
    target_file_name = re.sub('[0-9]', '', file_name) 
    if '_' in target_file_name:
        target_file_name = target_file_name.split('_')[-1]

    ctr = str(0)
    
    if 'بسم الله'  in target_file_name + '_'+ ctr +'.json':
        print(target_file_name + '_'+ ctr +'.json')
        print([f.split('/')[-1] for f in glob.glob('dataset/**/**.json') if 'بسم الله' in f] )
    while target_file_name + '_'+ ctr +'.json' in [f.split('/')[-1] for f in glob.glob('dataset/**/**.json')]:
        target_file_name = target_file_name + '_'+ ctr 
        ctr = str(int(ctr) + 1) 
   
    if i < 2000:
        shutil.copyfile(file, f'dataset/train/{target_file_name}.json')
    elif i < 2250:
        shutil.copyfile(file, f'dataset/valid/{target_file_name}.json')
    elif i < 2500:
        shutil.copyfile(file, f'dataset/test/{target_file_name}.json')
    else:
        break
# Out:
# بسم الله الرحمن الرحيم_0.json
# ['خريستوس.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'وهو على كل شيء قدير.json', 'هولي.json', 'دومينيك.json', 'ياسمين.json', 'ارمان.json', 'سبحان الله.json', 'لا يصدعون عنها ولا ينزفون.json', 'عزام.json', 'وسارعوا إلى مغفرة من ربكم.json', 'عصام.json', 'واعتصموا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'أنا لست لي.json', 'لا إله إلا الله محمد رسول الله.json', 'غويلم.json', 'كارولينا.json', 'تاهل.json', 'عرفان.json', 'خالد.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'كن فيكون.json', 'فائقة.json', 'طهورة.json', 'وخالق الناس بخلق حسن.json', 'عبد الله.json', 'المثنى.json', 'عشق.json', 'فرزانة.json', 'غوبي.json', 'الحمد لله.json', 'لا تحزن ان الله معنا.json', 'مانموهان.json', 'عائلة.json', 'محمد رسول الله.json', 'قل هو الرحمن امنا به و عليه توكلنا.json', 'نايا.json', 'أمالية.json', 'عمرو.json', 'أستون.json', 'محمد الكاظمي.json', 'وما بكم من نعمة فمن الله.json', 'محمد صلى الله عليه و سلم.json', 'ألم يعلم بأن الله يرى.json', 'رب اغفر لي ولوالدي.json', 'و هو على كل شيء قدير.json', 'ع م ن ص و.json', 'قل اعوذ برب الفلق.json', 'اعلموا أنما الحيوة الدنيا لعب ولهو.json', 'مروان.json', 'ما عفا رجل عن مظلمة إلا زاده الله عزا.json', 'يالله.json', 'ومن آياته أن خلق لكم من أنفسكم أزواجا.json', 'و قل رب زدنى علما.json', 'المانع.json', 'و أنه هو أضحك و أبكى.json', 'قد أفلح من تزكى.json', 'أحمد.json', 'وأقيموا الصلاة وآتوا الزكاة وأركعوا مع الراكعين.json', 'ووجدك عائلا فاغنى.json', 'بهاء.json', 'عمر.json']
# بسم الله الرحمن الرحيم_0.json
# ['خريستوس.json', 'سنا.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'وهو على كل شيء قدير.json', 'عيد مبارك.json', 'هولي.json', 'دومينيك.json', 'ياسمين.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'سبحان الله.json', 'لا يصدعون عنها ولا ينزفون.json', 'عزام.json', 'عنان.json', 'ميثاء.json', 'وسارعوا إلى مغفرة من ربكم.json', 'القناعة كنز لا يفنى.json', 'عصام.json', 'كانديلا.json', 'واعتصموا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'أنا لست لي.json', 'باتريشا.json', 'لا إله إلا الله محمد رسول الله.json', 'غويلم.json', 'كارولينا.json', 'تاهل.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'خالد.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'كن فيكون.json', 'فائقة.json', 'طهورة.json', 'وخالق الناس بخلق حسن.json', 'عبد الله.json', 'المثنى.json', 'عشق.json', 'يا رسول الله.json', 'فرزانة.json', 'ولدار الآخرة خير ولنعم دار المتقين.json', 'غوبي.json', 'الحمد لله.json', 'عام الخط العربي.json', 'رب نجني من القوم الظالمين.json', 'لا تحزن ان الله معنا.json', 'مانموهان.json', 'عائلة.json', 'محمد رسول الله.json', 'شوقوط.json', 'قل هو الرحمن امنا به و عليه توكلنا.json', 'نايا.json', 'أمالية.json', 'الله اكبر.json', 'عمرو.json', 'أستون.json', 'محمد الكاظمي.json', 'ياكريم.json', 'وما بكم من نعمة فمن الله.json', 'محمد صلى الله عليه و سلم.json', 'ألم يعلم بأن الله يرى.json', 'رب اغفر لي ولوالدي.json', 'و هو على كل شيء قدير.json', 'ع م ن ص و.json', 'قل اعوذ برب الفلق.json', 'اعلموا أنما الحيوة الدنيا لعب ولهو.json', 'مروان.json', 'ما عفا رجل عن مظلمة إلا زاده الله عزا.json', 'يالله.json', 'ومن آياته أن خلق لكم من أنفسكم أزواجا.json', 'و قل رب زدنى علما.json', 'المانع.json', 'و أنه هو أضحك و أبكى.json', 'قد أفلح من تزكى.json', 'أحمد.json', 'وأقيموا الصلاة وآتوا الزكاة وأركعوا مع الراكعين.json', 'ووجدك عائلا فاغنى.json', 'ن و القلم و ما يسطرون.json', 'بهاء.json', 'عمر.json']
# بسم الله الرحمن الرحيم_0.json
# ['خريستوس.json', 'سنا.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'وهو على كل شيء قدير.json', 'عيد مبارك.json', 'هولي.json', 'دومينيك.json', 'ياسمين.json', 'كلماتنا في الحب تقتل حبنا.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'سبحان الله.json', 'لا يصدعون عنها ولا ينزفون.json', 'عزام.json', 'عنان.json', 'ميثاء.json', 'الله.json', 'وسارعوا إلى مغفرة من ربكم.json', 'إقرأ كتابك كفى بنفسك اليوم عليك حسيبا.json', 'القناعة كنز لا يفنى.json', 'زهرة العراق.json', 'عصام.json', 'كانديلا.json', 'واعتصموا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'أنا لست لي.json', 'باتريشا.json', 'سمر.json', 'فرح.json', 'لا إله إلا الله محمد رسول الله.json', 'طوني.json', 'غويلم.json', 'كارولينا.json', 'تاهل.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'و لكن الله الف بينهم.json', 'خالد.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'كن فيكون.json', 'فائقة.json', 'طهورة.json', 'وخالق الناس بخلق حسن.json', 'تنزيله.json', 'هذا من فضل ربي.json', 'عبد الله.json', 'المثنى.json', 'عشق.json', 'والله يعلم وأنتم لا تعلمون.json', 'يا رسول الله.json', 'فرزانة.json', 'ولدار الآخرة خير ولنعم دار المتقين.json', 'وما ارسلناك إلا رحمة للعالمين.json', 'غوبي.json', 'الحمد لله.json', 'عام الخط العربي.json', 'رب نجني من القوم الظالمين.json', 'وا.json', 'لا تحزن ان الله معنا.json', ' لا اله الا الله محمد رسول الله.json', 'وسعت رحمتي كل شيء.json', 'مانموهان.json', 'عائلة.json', 'جومانا.json', 'محمد رسول الله.json', 'شوقوط.json', 'نتيجة.json', 'قل هو الرحمن امنا به و عليه توكلنا.json', 'زينب.json', 'نايا.json', 'أمالية.json', 'الله اكبر.json', 'عمرو.json', 'أستون.json', 'محمد الكاظمي.json', 'ياكريم.json', 'وما بكم من نعمة فمن الله.json', 'محمد صلى الله عليه و سلم.json', 'ألم يعلم بأن الله يرى.json', 'فرانشيسكو.json', 'رب اغفر لي ولوالدي.json', 'و هو على كل شيء قدير.json', 'ع م ن ص و.json', 'قل اعوذ برب الفلق.json', 'اعلموا أنما الحيوة الدنيا لعب ولهو.json', 'مروان.json', 'ما عفا رجل عن مظلمة إلا زاده الله عزا.json', 'يالله.json', 'ومن آياته أن خلق لكم من أنفسكم أزواجا.json', 'و قل رب زدنى علما.json', 'المانع.json', 'و أنه هو أضحك و أبكى.json', 'قد أفلح من تزكى.json', 'أحمد.json', 'وأقيموا الصلاة وآتوا الزكاة وأركعوا مع الراكعين.json', 'امبييه.json', 'الرحيم.json', 'ووجدك عائلا فاغنى.json', 'ن و القلم و ما يسطرون.json', 'بهاء.json', 'عمر.json']
# بسم الله_0.json
# ['وكلهم اتيه يوم القيامة فردا.json', 'خريستوس.json', 'سنا.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'وهو على كل شيء قدير.json', 'أني مسني الشيطن بنصب وعذاب.json', 'عيد مبارك.json', 'هولي.json', 'دومينيك.json', 'ياسمين.json', 'كلماتنا في الحب تقتل حبنا.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'الحكم.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'سبحان الله.json', 'لا يصدعون عنها ولا ينزفون.json', 'عزام.json', 'عنان.json', 'محمد خير من يمشي على قدم.json', 'ميثاء.json', 'الله.json', 'فطيم.json', 'وسارعوا إلى مغفرة من ربكم.json', 'إقرأ كتابك كفى بنفسك اليوم عليك حسيبا.json', 'القناعة كنز لا يفنى.json', 'زهرة العراق.json', 'عصام.json', 'كانديلا.json', 'واعتصموا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'أنا لست لي.json', 'باتريشا.json', 'سمر.json', 'فرح.json', 'لا إله إلا الله محمد رسول الله.json', 'طوني.json', 'غويلم.json', 'كارولينا.json', 'تاهل.json', 'علي رضي الله عنه.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'و لكن الله الف بينهم.json', 'خالد.json', 'جلوريا.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'وكان فضل الله عليك عظيما.json', 'إن الله مع الذين اتقوا والذين هم محسنون.json', 'كن فيكون.json', 'الحمد لله رب العالمين.json', 'فائقة.json', 'طهورة.json', ' والله غالب على أمره.json', 'وخالق الناس بخلق حسن.json', 'تنزيله.json', 'هذا من فضل ربي.json', 'عبد الله.json', 'المثنى.json', 'عشق.json', 'والله يعلم وأنتم لا تعلمون.json', 'يا رسول الله.json', 'فرزانة.json', 'ولدار الآخرة خير ولنعم دار المتقين.json', 'عبد الرشيد.json', 'وما ارسلناك إلا رحمة للعالمين.json', 'لئن شكرتم لازيدنكم.json', 'المؤمن لا يكذب.json', 'ألا بذكر الله تطمئن القلوب.json', 'غوبي.json', 'الحمد لله.json', 'عام الخط العربي.json', 'رب نجني من القوم الظالمين.json', 'وا.json', 'لا اشجار تموت واقفة.json', 'لا تحزن ان الله معنا.json', ' لا اله الا الله محمد رسول الله.json', 'سلام.json', 'وسعت رحمتي كل شيء.json', 'مانموهان.json', 'عائلة.json', 'عيد أضحى مبارك.json', 'جومانا.json', 'وأما بنعمة ربك فحدث.json', 'محمد رسول الله.json', 'شوقوط.json', 'نتيجة.json', 'قل هو الرحمن امنا به و عليه توكلنا.json', 'زينب.json', 'نايا.json', 'عيد سعيد.json', 'أمالية.json', 'الله اكبر.json', 'عمرو.json', 'أستون.json', 'شاهين.json', 'محمد الكاظمي.json', 'ياكريم.json', 'قل أعوذ برب الناس.json', 'وما بكم من نعمة فمن الله.json', 'محمد صلى الله عليه و سلم.json', 'ألم يعلم بأن الله يرى.json', 'فرانشيسكو.json', 'وووو.json', 'رب اغفر لي ولوالدي.json', 'و هو على كل شيء قدير.json', 'ع م ن ص و.json', 'حفصة.json', 'قل اعوذ برب الفلق.json', 'وانك لعلى خلق عظيم.json', 'اعلموا أنما الحيوة الدنيا لعب ولهو.json', 'مروان.json', 'ما عفا رجل عن مظلمة إلا زاده الله عزا.json', 'القرءان الكريم.json', 'يالله.json', 'ومن آياته أن خلق لكم من أنفسكم أزواجا.json', 'و قل رب زدنى علما.json', 'المانع.json', 'و أنه هو أضحك و أبكى.json', 'قد أفلح من تزكى.json', 'رمضان كريم.json', 'كارديلو.json', 'والذين أمنوا أشد حبا لله.json', 'هي جنة.json', 'عليك عون الله.json', 'أحمد.json', 'هو الفتاح العليم.json', 'وأقيموا الصلاة وآتوا الزكاة وأركعوا مع الراكعين.json', 'ايحسب الانسان أن يترك سدى.json', 'امبييه.json', 'الرحيم.json', 'ووجدك عائلا فاغنى.json', 'ن و القلم و ما يسطرون.json', 'بهاء.json', 'عمر.json']
# بسم الله الرحمن الرحيم_0.json
# ['وكلهم اتيه يوم القيامة فردا.json', 'خريستوس.json', 'سنا.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'كل عام وأنتم بخير.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'دومه.json', 'اشهد ان لا آله الا الله واشهد ان محمد عبده ورسوله.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'برديس.json', 'وهو على كل شيء قدير.json', 'أني مسني الشيطن بنصب وعذاب.json', 'عيد مبارك.json', 'هولي.json', 'دومينيك.json', 'ياسمين.json', 'كلماتنا في الحب تقتل حبنا.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'عذبة.json', 'شرق الرياض.json', 'ايريك.json', 'الحكم.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'وإني لغفار لمن تاب وأمن وعمل صالحا ثم اهتدى.json', 'سبحان الله.json', 'لا يصدعون عنها ولا ينزفون.json', 'عزام.json', 'عنان.json', 'محمد خير من يمشي على قدم.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'ميثاء.json', 'الله.json', 'فطيم.json', 'وسارعوا إلى مغفرة من ربكم.json', 'إقرأ كتابك كفى بنفسك اليوم عليك حسيبا.json', 'القناعة كنز لا يفنى.json', 'انا فتحنا لك فتحا مبينا.json', 'زهرة العراق.json', 'عصام.json', 'كانديلا.json', 'رمضان مبارك.json', 'واعتصموا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'الخط يبقى زمانا بعد كاتبه و كاتب الخط تحت الأرض مدفون.json', 'ولسوف يعطيك ربك فترضى.json', 'أنا لست لي.json', 'باتريشا.json', 'سمر.json', 'فرح.json', 'لا إله إلا الله محمد رسول الله.json', 'ووو.json', 'طوني.json', 'غويلم.json', 'كارولينا.json', 'تاهل.json', 'ان في الخيال حياة.json', 'علي رضي الله عنه.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'و لكن الله الف بينهم.json', 'خالد.json', 'جلوريا.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'وكان فضل الله عليك عظيما.json', 'إن الله مع الذين اتقوا والذين هم محسنون.json', 'كن فيكون.json', 'الحمد لله رب العالمين.json', 'هل جزاء الإحسان الا الإحسان فبأى آلاء ربكما تكذبان.json', 'فائقة.json', 'طهورة.json', 'إن الله كان توابا رحيما.json', 'مازن.json', ' والله غالب على أمره.json', 'وخالق الناس بخلق حسن.json', 'تنزيله.json', 'هذا من فضل ربي.json', 'عبد الله.json', 'انما اشكو بثي وحزني الى الله.json', 'المثنى.json', 'ذاناي.json', 'عشق.json', 'والله يعلم وأنتم لا تعلمون.json', 'يا رسول الله.json', 'فرزانة.json', 'ولدار الآخرة خير ولنعم دار المتقين.json', 'عبد الرشيد.json', 'وما ارسلناك إلا رحمة للعالمين.json', 'لئن شكرتم لازيدنكم.json', 'غادة الدالي.json', 'المؤمن لا يكذب.json', 'ألا بذكر الله تطمئن القلوب.json', 'غوبي.json', 'إن الله جميل يحب الجمال.json', 'الحمد لله.json', 'عام الخط العربي.json', 'رب نجني من القوم الظالمين.json', 'وا.json', 'لا اشجار تموت واقفة.json', 'لا تحزن ان الله معنا.json', ' لا اله الا الله محمد رسول الله.json', 'سلام.json', 'وسعت رحمتي كل شيء.json', 'ماشاء الله.json', 'مانموهان.json', 'عائلة.json', 'عيد أضحى مبارك.json', 'جومانا.json', 'وأما بنعمة ربك فحدث.json', 'جمهوريتي توركيه.json', 'محمد رسول الله.json', 'آيات.json', 'شوقوط.json', 'نتيجة.json', 'قل هو الرحمن امنا به و عليه توكلنا.json', 'زينب.json', 'نايا.json', 'عيد سعيد.json', 'أمالية.json', 'الله اكبر.json', 'عمرو.json', 'أستون.json', 'شاهين.json', 'محمد الكاظمي.json', 'ياكريم.json', 'قل أعوذ برب الناس.json', 'وما بكم من نعمة فمن الله.json', 'محمد صلى الله عليه و سلم.json', 'ألم يعلم بأن الله يرى.json', 'فرانشيسكو.json', 'وووو.json', 'رب اغفر لي ولوالدي.json', 'و هو على كل شيء قدير.json', 'ع م ن ص و.json', 'حفصة.json', 'قل اعوذ برب الفلق.json', 'وانك لعلى خلق عظيم.json', 'اعلموا أنما الحيوة الدنيا لعب ولهو.json', 'زارا.json', 'مروان.json', 'ما عفا رجل عن مظلمة إلا زاده الله عزا.json', 'القرءان الكريم.json', 'محمد احمد محمود.json', 'يالله.json', 'ذكريات.json', 'ومن آياته أن خلق لكم من أنفسكم أزواجا.json', 'و قل رب زدنى علما.json', 'المانع.json', 'و أنه هو أضحك و أبكى.json', 'قد أفلح من تزكى.json', 'رمضان كريم.json', 'كارديلو.json', 'حب.json', 'والذين أمنوا أشد حبا لله.json', 'هي جنة.json', 'عليك عون الله.json', 'أحمد.json', 'بسم الله.json', 'هو الفتاح العليم.json', 'وأقيموا الصلاة وآتوا الزكاة وأركعوا مع الراكعين.json', 'ايحسب الانسان أن يتر ...
# بسم الله الرحمن الرحيم_0.json
# ['وكلهم اتيه يوم القيامة فردا.json', 'خريستوس.json', 'سنا.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'كل عام وأنتم بخير.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'دومه.json', 'اشهد ان لا آله الا الله واشهد ان محمد عبده ورسوله.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'برديس.json', 'وهو على كل شيء قدير.json', 'أني مسني الشيطن بنصب وعذاب.json', 'عيد مبارك.json', 'هولي.json', 'دومينيك.json', 'ياسمين.json', 'كلماتنا في الحب تقتل حبنا.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'كنزي.json', 'عذبة.json', 'شرق الرياض.json', 'ايريك.json', 'الحكم.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'وإني لغفار لمن تاب وأمن وعمل صالحا ثم اهتدى.json', 'سبحان الله.json', 'لا يصدعون عنها ولا ينزفون.json', 'أمينة.json', 'عزام.json', 'عنان.json', 'محمد خير من يمشي على قدم.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'ميثاء.json', 'الله.json', 'فطيم.json', 'وسارعوا إلى مغفرة من ربكم.json', 'إقرأ كتابك كفى بنفسك اليوم عليك حسيبا.json', 'القناعة كنز لا يفنى.json', 'انا فتحنا لك فتحا مبينا.json', 'زهرة العراق.json', 'عصام.json', 'كانديلا.json', 'رمضان مبارك.json', 'واعتصموا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'الخط يبقى زمانا بعد كاتبه و كاتب الخط تحت الأرض مدفون.json', 'شيماء.json', 'ولسوف يعطيك ربك فترضى.json', 'أنا لست لي.json', 'باتريشا.json', 'سمر.json', 'فرح.json', 'لا إله إلا الله محمد رسول الله.json', 'ووو.json', 'طوني.json', 'غويلم.json', 'كارولينا.json', 'تاهل.json', 'ان في الخيال حياة.json', 'علي رضي الله عنه.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'و لكن الله الف بينهم.json', 'خالد.json', 'جلوريا.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'وكان فضل الله عليك عظيما.json', 'إن الله مع الذين اتقوا والذين هم محسنون.json', 'كن فيكون.json', 'الحمد لله رب العالمين.json', 'هل جزاء الإحسان الا الإحسان فبأى آلاء ربكما تكذبان.json', 'فائقة.json', 'طهورة.json', 'إن الله كان توابا رحيما.json', 'مازن.json', ' والله غالب على أمره.json', 'وخالق الناس بخلق حسن.json', 'تنزيله.json', 'هذا من فضل ربي.json', 'عبد الله.json', 'انما اشكو بثي وحزني الى الله.json', 'المثنى.json', 'ذاناي.json', 'عشق.json', 'والله يعلم وأنتم لا تعلمون.json', 'يا رسول الله.json', 'فرزانة.json', 'ولدار الآخرة خير ولنعم دار المتقين.json', 'عبد الرشيد.json', 'وما ارسلناك إلا رحمة للعالمين.json', 'لئن شكرتم لازيدنكم.json', 'غادة الدالي.json', 'المؤمن لا يكذب.json', 'ألا بذكر الله تطمئن القلوب.json', 'غوبي.json', 'إن الله جميل يحب الجمال.json', 'الحمد لله.json', 'الله جل جلاله.json', 'عام الخط العربي.json', 'رب نجني من القوم الظالمين.json', 'وا.json', 'لا اشجار تموت واقفة.json', 'لا تحزن ان الله معنا.json', ' لا اله الا الله محمد رسول الله.json', 'سلام.json', 'وسعت رحمتي كل شيء.json', 'ماشاء الله.json', 'مانموهان.json', 'عائلة.json', 'عيد أضحى مبارك.json', 'جومانا.json', 'وأما بنعمة ربك فحدث.json', 'جمهوريتي توركيه.json', 'محمد رسول الله.json', 'آيات.json', 'شوقوط.json', 'نتيجة.json', 'قل هو الرحمن امنا به و عليه توكلنا.json', 'زينب.json', 'نايا.json', 'عيد سعيد.json', 'أمالية.json', 'الله اكبر.json', 'عمرو.json', 'أستون.json', 'شاهين.json', 'محمد الكاظمي.json', 'ياكريم.json', 'قل أعوذ برب الناس.json', 'وما بكم من نعمة فمن الله.json', 'جمالت.json', 'محمد صلى الله عليه و سلم.json', 'ألم يعلم بأن الله يرى.json', 'فرانشيسكو.json', 'وووو.json', 'رب اغفر لي ولوالدي.json', 'و هو على كل شيء قدير.json', 'ع م ن ص و.json', 'حفصة.json', 'قل اعوذ برب الفلق.json', 'وانك لعلى خلق عظيم.json', 'اعلموا أنما الحيوة الدنيا لعب ولهو.json', 'زارا.json', 'مروان.json', 'اللهم انك عفو تحب العفو فاعف عنا.json', 'القلب يحن.json', 'ما عفا رجل عن مظلمة إلا زاده الله عزا.json', 'القرءان الكريم.json', 'محمد احمد محمود.json', 'يالله.json', 'ذكريات.json', 'ومن آياته أن خلق لكم من أنفسكم أزواجا.json', 'و قل رب زدنى علما.json', 'المانع.json', 'و أنه هو أضحك و أبكى.json', 'قد أفلح من تزكى.json', 'رمضان كريم.json', 'كارديلو.json', 'حب.json', 'والذين أمنوا أشد حبا لله.json', 'هي جنة.json', 'عليك عون الله.jso ...
# بسم الله الرحمن الرحيم_0.json
# ['وكلهم اتيه يوم القيامة فردا.json', 'خريستوس.json', 'سنا.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'كل عام وأنتم بخير.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'دومه.json', 'اشهد ان لا آله الا الله واشهد ان محمد عبده ورسوله.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'برديس.json', 'وهو على كل شيء قدير.json', 'أني مسني الشيطن بنصب وعذاب.json', 'عيد مبارك.json', 'هولي.json', 'دومينيك.json', 'ياسمين.json', 'كلماتنا في الحب تقتل حبنا.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'كنزي.json', 'عذبة.json', 'شرق الرياض.json', 'ايريك.json', 'الحكم.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'وإني لغفار لمن تاب وأمن وعمل صالحا ثم اهتدى.json', 'سبحان الله.json', 'لا يصدعون عنها ولا ينزفون.json', 'أمينة.json', 'عزام.json', 'عنان.json', 'محمد خير من يمشي على قدم.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'ميثاء.json', 'الله.json', 'فطيم.json', 'وسارعوا إلى مغفرة من ربكم.json', 'إقرأ كتابك كفى بنفسك اليوم عليك حسيبا.json', 'القناعة كنز لا يفنى.json', 'انا فتحنا لك فتحا مبينا.json', 'زهرة العراق.json', 'عصام.json', 'كانديلا.json', 'رمضان مبارك.json', 'واعتصموا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'الخط يبقى زمانا بعد كاتبه و كاتب الخط تحت الأرض مدفون.json', 'شيماء.json', 'ولسوف يعطيك ربك فترضى.json', 'أنا لست لي.json', 'باتريشا.json', 'سمر.json', 'فرح.json', 'لا إله إلا الله محمد رسول الله.json', 'ووو.json', 'طوني.json', 'غويلم.json', 'كارولينا.json', 'تاهل.json', 'ان في الخيال حياة.json', 'علي رضي الله عنه.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'و لكن الله الف بينهم.json', 'خالد.json', 'جلوريا.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'وكان فضل الله عليك عظيما.json', 'إن الله مع الذين اتقوا والذين هم محسنون.json', 'كن فيكون.json', 'الحمد لله رب العالمين.json', 'هل جزاء الإحسان الا الإحسان فبأى آلاء ربكما تكذبان.json', 'فائقة.json', 'طهورة.json', 'إن الله كان توابا رحيما.json', 'مازن.json', ' والله غالب على أمره.json', 'وخالق الناس بخلق حسن.json', 'تنزيله.json', 'هذا من فضل ربي.json', 'عبد الله.json', 'انما اشكو بثي وحزني الى الله.json', 'المثنى.json', 'ذاناي.json', 'عشق.json', 'والله يعلم وأنتم لا تعلمون.json', 'يا رسول الله.json', 'فرزانة.json', 'ولدار الآخرة خير ولنعم دار المتقين.json', 'عبد الرشيد.json', 'وما ارسلناك إلا رحمة للعالمين.json', 'لئن شكرتم لازيدنكم.json', 'غادة الدالي.json', 'المؤمن لا يكذب.json', 'ألا بذكر الله تطمئن القلوب.json', 'غوبي.json', 'إن الله جميل يحب الجمال.json', 'الحمد لله.json', 'الله جل جلاله.json', 'عام الخط العربي.json', 'رب نجني من القوم الظالمين.json', 'وا.json', 'لا اشجار تموت واقفة.json', 'لا تحزن ان الله معنا.json', ' لا اله الا الله محمد رسول الله.json', 'سلام.json', 'وسعت رحمتي كل شيء.json', 'ماشاء الله.json', 'مانموهان.json', 'عائلة.json', 'عيد أضحى مبارك.json', 'جومانا.json', 'وأما بنعمة ربك فحدث.json', 'جمهوريتي توركيه.json', 'محمد رسول الله.json', 'آيات.json', 'شوقوط.json', 'نتيجة.json', 'قل هو الرحمن امنا به و عليه توكلنا.json', 'زينب.json', 'نايا.json', 'عيد سعيد.json', 'أمالية.json', 'الله اكبر.json', 'عمرو.json', 'أستون.json', 'شاهين.json', 'محمد الكاظمي.json', 'ياكريم.json', 'قل أعوذ برب الناس.json', 'وما بكم من نعمة فمن الله.json', 'جمالت.json', 'محمد صلى الله عليه و سلم.json', 'ألم يعلم بأن الله يرى.json', 'فرانشيسكو.json', 'وووو.json', 'رب اغفر لي ولوالدي.json', 'و هو على كل شيء قدير.json', 'ع م ن ص و.json', 'حفصة.json', 'قل اعوذ برب الفلق.json', 'وقل رب انزلني منزلا مباركا وانت خير المنزلين.json', 'نينا.json', 'وانك لعلى خلق عظيم.json', 'اعلموا أنما الحيوة الدنيا لعب ولهو.json', 'زارا.json', 'مروان.json', 'اللهم انك عفو تحب العفو فاعف عنا.json', 'القلب يحن.json', 'ما عفا رجل عن مظلمة إلا زاده الله عزا.json', 'القرءان الكريم.json', 'محمد احمد محمود.json', 'يالله.json', 'ذكريات.json', 'ومن آياته أن خلق لكم من أنفسكم أزواجا.json', 'و قل رب زدنى علما.json', 'المانع.json', 'و أنه هو أضحك و أبكى.json', 'قد أفلح من تزكى.json', 'رمضان كريم.json', 'كارديلو.json', 'حب.json',  ...
# بسم الله الرحمن الرحيم_0.json
# ['وكلهم اتيه يوم القيامة فردا.json', 'لا اله الا الله محمد رسول الله.json', 'خريستوس.json', 'سنا.json', 'لا تيأسوا من روح الله.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'كل عام وأنتم بخير.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'دومه.json', 'اشهد ان لا آله الا الله واشهد ان محمد عبده ورسوله.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'برديس.json', 'وهو على كل شيء قدير.json', 'أني مسني الشيطن بنصب وعذاب.json', 'عيد مبارك.json', 'هولي.json', 'دومينيك.json', 'ياسمين.json', 'كلماتنا في الحب تقتل حبنا.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'نيشا.json', 'كنزي.json', 'عذبة.json', 'علية.json', 'شرق الرياض.json', 'ايريك.json', 'الحكم.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'وإني لغفار لمن تاب وأمن وعمل صالحا ثم اهتدى.json', 'سبحان الله.json', 'لا يصدعون عنها ولا ينزفون.json', 'أمينة.json', 'عزام.json', 'هني.json', 'عنان.json', 'محمد خير من يمشي على قدم.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'ميثاء.json', 'الله.json', 'فطيم.json', 'وسارعوا إلى مغفرة من ربكم.json', 'إقرأ كتابك كفى بنفسك اليوم عليك حسيبا.json', 'القناعة كنز لا يفنى.json', 'انا فتحنا لك فتحا مبينا.json', 'زهرة العراق.json', 'قل هو الله احد.json', 'عصام.json', 'كانديلا.json', ' يسبح لله ما في السموات وما فى الأرض.json', 'رمضان مبارك.json', 'واعتصموا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'الخط يبقى زمانا بعد كاتبه و كاتب الخط تحت الأرض مدفون.json', 'شيماء.json', 'ولسوف يعطيك ربك فترضى.json', 'أنا لست لي.json', 'باتريشا.json', 'سمر.json', 'فرح.json', 'لا إله إلا الله محمد رسول الله.json', 'ووو.json', 'طوني.json', 'غويلم.json', 'كارولينا.json', 'تاهل.json', 'ان في الخيال حياة.json', 'علي رضي الله عنه.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'و لكن الله الف بينهم.json', 'خالد.json', 'جلوريا.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'وكان فضل الله عليك عظيما.json', 'إن الله مع الذين اتقوا والذين هم محسنون.json', 'كن فيكون.json', 'اليس الله بأحكم الحاكمين.json', 'الحمد لله رب العالمين.json', 'هل جزاء الإحسان الا الإحسان فبأى آلاء ربكما تكذبان.json', 'وعد الله الذين آمنوا وعملوا الصالحات لهم مغفرة واجر عظيم.json', 'فائقة.json', 'فيصل.json', 'افحسبتم أنما خلقناكم عبثا وأنكم الينا لا ترجعون.json', 'طهورة.json', 'إن الله كان توابا رحيما.json', 'مازن.json', ' والله غالب على أمره.json', 'وخالق الناس بخلق حسن.json', 'تنزيله.json', 'هذا من فضل ربي.json', 'عبد الله.json', 'انما اشكو بثي وحزني الى الله.json', 'ديانا.json', 'المثنى.json', 'ذاناي.json', 'عشق.json', 'والله يعلم وأنتم لا تعلمون.json', 'يا رسول الله.json', 'فرزانة.json', 'ولدار الآخرة خير ولنعم دار المتقين.json', 'عبد الرشيد.json', 'وما ارسلناك إلا رحمة للعالمين.json', 'لئن شكرتم لازيدنكم.json', 'غادة الدالي.json', 'المؤمن لا يكذب.json', 'ألا بذكر الله تطمئن القلوب.json', 'غوبي.json', 'إن الله جميل يحب الجمال.json', 'الحمد لله.json', 'الله جل جلاله.json', 'عام الخط العربي.json', 'رب نجني من القوم الظالمين.json', 'عي.json', 'وا.json', 'لا اشجار تموت واقفة.json', 'لا تحزن ان الله معنا.json', ' لا اله الا الله محمد رسول الله.json', 'عبد الرحمن.json', 'عامر.json', 'سلام.json', 'وسعت رحمتي كل شيء.json', 'ماشاء الله.json', 'مانموهان.json', 'عائلة.json', 'عيد أضحى مبارك.json', 'جومانا.json', 'وأما بنعمة ربك فحدث.json', 'جمهوريتي توركيه.json', 'محمد رسول الله.json', 'آيات.json', 'شوقوط.json', 'نتيجة.json', 'قل هو الرحمن امنا به و عليه توكلنا.json', 'قل هو الله أحد الله الصمد.json', 'زينب.json', 'نايا.json', 'عيد سعيد.json', 'أمالية.json', 'الله اكبر.json', 'عمرو.json', 'أستون.json', 'شاهين.json', 'محمد الكاظمي.json', 'ياكريم.json', 'قل أعوذ برب الناس.json', 'وما بكم من نعمة فمن الله.json', 'جمالت.json', 'محمد صلى الله عليه و سلم.json', 'ألم يعلم بأن الله يرى.json', 'فرانشيسكو.json', 'لا إله الا الله محمد رسول الله.json', 'وووو.json', 'رب اغفر لي ولوالدي.json', 'و هو على كل شيء قدير.json', 'ع م ن ص و.json', 'حفصة.json', 'قل اعوذ برب الفلق.json', 'وقل رب انزلني منزلا مباركا وانت خير المنزلين.json', 'نينا ...
# بسم الله الرحمن الرحيم_0.json
# ['وكلهم اتيه يوم القيامة فردا.json', 'لا اله الا الله محمد رسول الله.json', 'خريستوس.json', 'سنا.json', 'لا تيأسوا من روح الله.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'كل عام وأنتم بخير.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'الجزيرة.json', 'دومه.json', 'اشهد ان لا آله الا الله واشهد ان محمد عبده ورسوله.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'برديس.json', 'وهو على كل شيء قدير.json', 'أني مسني الشيطن بنصب وعذاب.json', 'عيد مبارك.json', 'هولي.json', 'دومينيك.json', 'ياسمين.json', 'كلماتنا في الحب تقتل حبنا.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'نيشا.json', 'كنزي.json', 'عذبة.json', 'علية.json', 'شرق الرياض.json', 'ايريك.json', 'الحكم.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'وإني لغفار لمن تاب وأمن وعمل صالحا ثم اهتدى.json', 'سبحان الله.json', 'لا يصدعون عنها ولا ينزفون.json', 'أمينة.json', 'عزام.json', 'هني.json', 'عنان.json', 'محمد خير من يمشي على قدم.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'ميثاء.json', 'الله.json', 'فطيم.json', 'وسارعوا إلى مغفرة من ربكم.json', 'إقرأ كتابك كفى بنفسك اليوم عليك حسيبا.json', 'ق و القرآن المجيد.json', 'القناعة كنز لا يفنى.json', 'انا فتحنا لك فتحا مبينا.json', 'زهرة العراق.json', 'قل هو الله احد.json', 'عصام.json', 'كانديلا.json', 'فسيكفيكهم الله وهو السميع العليم.json', ' يسبح لله ما في السموات وما فى الأرض.json', 'رمضان مبارك.json', 'واعتصموا.json', 'لوكا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'الخط يبقى زمانا بعد كاتبه و كاتب الخط تحت الأرض مدفون.json', 'شيماء.json', 'ولسوف يعطيك ربك فترضى.json', 'أنا لست لي.json', 'باتريشا.json', 'سمر.json', 'فرح.json', 'لا إله إلا الله محمد رسول الله.json', 'ووو.json', 'طوني.json', 'غويلم.json', 'كارولينا.json', 'تاهل.json', 'ان في الخيال حياة.json', 'علي رضي الله عنه.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'و لكن الله الف بينهم.json', 'خالد.json', 'جلوريا.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'وكان فضل الله عليك عظيما.json', 'إن الله مع الذين اتقوا والذين هم محسنون.json', 'كن فيكون.json', 'ولا تهنو ولا تحزنوا وأنتم الأعلون إن كنتم مؤمنين.json', 'اليس الله بأحكم الحاكمين.json', 'الحمد لله رب العالمين.json', 'هل جزاء الإحسان الا الإحسان فبأى آلاء ربكما تكذبان.json', 'وعد الله الذين آمنوا وعملوا الصالحات لهم مغفرة واجر عظيم.json', 'رب إني ظلمت نفسي فاغفرلي.json', 'فائقة.json', 'فيصل.json', 'افحسبتم أنما خلقناكم عبثا وأنكم الينا لا ترجعون.json', 'ينس.json', 'طهورة.json', 'إن الله كان توابا رحيما.json', 'مازن.json', 'وماتوفيقي إلا بالله.json', ' والله غالب على أمره.json', 'وخالق الناس بخلق حسن.json', 'تنزيله.json', 'هذا من فضل ربي.json', 'عبد الله.json', 'انما اشكو بثي وحزني الى الله.json', 'ديانا.json', 'المثنى.json', 'ذاناي.json', 'عشق.json', 'والله يعلم وأنتم لا تعلمون.json', 'يا رسول الله.json', 'فرزانة.json', 'ولدار الآخرة خير ولنعم دار المتقين.json', 'عبد الرشيد.json', 'وما ارسلناك إلا رحمة للعالمين.json', 'لئن شكرتم لازيدنكم.json', 'غادة الدالي.json', 'المؤمن لا يكذب.json', 'ألا بذكر الله تطمئن القلوب.json', 'غوبي.json', 'إن الله جميل يحب الجمال.json', 'الحمد لله.json', 'الله جل جلاله.json', 'الله في عون العبد مادام العبد في عون اخيه.json', 'عام الخط العربي.json', 'رب نجني من القوم الظالمين.json', 'عي.json', 'وا.json', 'لا اشجار تموت واقفة.json', 'لا تحزن ان الله معنا.json', ' لا اله الا الله محمد رسول الله.json', 'عبد الرحمن.json', 'عامر.json', 'سلام.json', 'وسعت رحمتي كل شيء.json', 'ماشاء الله.json', 'مانموهان.json', 'عائلة.json', 'عيد أضحى مبارك.json', 'جومانا.json', 'وأما بنعمة ربك فحدث.json', 'جمهوريتي توركيه.json', 'محمد رسول الله.json', 'آيات.json', 'شوقوط.json', 'الحب كذبتنا الصادقة.json', 'نتيجة.json', 'قل هو الرحمن امنا به و عليه توكلنا.json', 'ديمة.json', 'قل هو الله أحد الله الصمد.json', 'زينب.json', 'نايا.json', 'عيد سعيد.json', 'أمالية.json', 'الله اكبر.json', 'عمرو.json', 'أستون.json', 'شاهين.json', 'محمد الكاظمي.json', 'ياكريم.json', 'قل أعوذ برب الناس.json', 'وما بكم من نعمة فمن الله.json', ' ...
# بسم الله الرحمن الرحيم_0.json
# ['وكلهم اتيه يوم القيامة فردا.json', 'لا اله الا الله محمد رسول الله.json', 'خريستوس.json', 'سنا.json', 'لا تيأسوا من روح الله.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'كل عام وأنتم بخير.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'الجزيرة.json', 'دومه.json', 'اشهد ان لا آله الا الله واشهد ان محمد عبده ورسوله.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'برديس.json', 'وهو على كل شيء قدير.json', 'ولا تحسبن الله غافلا عما يعمل الظالمون.json', 'أني مسني الشيطن بنصب وعذاب.json', 'عيد مبارك.json', 'هولي.json', 'دومينيك.json', 'ياسمين.json', 'كلماتنا في الحب تقتل حبنا.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'رب إني لما أنزلت إلي من خير فقير.json', 'لا يدخل الجنة قاطع رحم.json', 'نيشا.json', 'كنزي.json', 'عذبة.json', 'علية.json', 'شرق الرياض.json', 'ايريك.json', 'الحكم.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'وإني لغفار لمن تاب وأمن وعمل صالحا ثم اهتدى.json', 'سبحان الله.json', 'لا يصدعون عنها ولا ينزفون.json', 'أمينة.json', 'عزام.json', 'هني.json', 'عنان.json', 'محمد خير من يمشي على قدم.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'ميثاء.json', 'الله.json', 'عيد كم مبارك.json', 'فطيم.json', 'وسارعوا إلى مغفرة من ربكم.json', 'إقرأ كتابك كفى بنفسك اليوم عليك حسيبا.json', 'ق و القرآن المجيد.json', 'القناعة كنز لا يفنى.json', 'انا فتحنا لك فتحا مبينا.json', 'زهرة العراق.json', 'قل هو الله احد.json', 'عصام.json', 'كانديلا.json', 'فسيكفيكهم الله وهو السميع العليم.json', ' يسبح لله ما في السموات وما فى الأرض.json', 'رمضان مبارك.json', 'واعتصموا.json', 'الحلم.json', 'لوكا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'الخط يبقى زمانا بعد كاتبه و كاتب الخط تحت الأرض مدفون.json', 'شيماء.json', 'ولسوف يعطيك ربك فترضى.json', 'أنا لست لي.json', 'الله يثبت.json', 'باتريشا.json', 'سمر.json', 'فرح.json', 'لا إله إلا الله محمد رسول الله.json', 'صباح الخير.json', 'ووو.json', 'طوني.json', 'راجية.json', 'غويلم.json', 'كارولينا.json', 'الحلم سيد الأخلاق.json', 'تاهل.json', 'النجاة في الصدق.json', 'ان في الخيال حياة.json', 'علي رضي الله عنه.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'و لكن الله الف بينهم.json', 'إيمان.json', 'خالد.json', 'الحق.json', 'جلوريا.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'وكان فضل الله عليك عظيما.json', 'اليس الله بكاف عبده.json', 'إن الله مع الذين اتقوا والذين هم محسنون.json', 'كن فيكون.json', 'ولا تهنو ولا تحزنوا وأنتم الأعلون إن كنتم مؤمنين.json', 'اليس الله بأحكم الحاكمين.json', 'الحمد لله رب العالمين.json', 'هل جزاء الإحسان الا الإحسان فبأى آلاء ربكما تكذبان.json', 'واذا مرضت فهو يشفين.json', 'وعد الله الذين آمنوا وعملوا الصالحات لهم مغفرة واجر عظيم.json', 'رب إني ظلمت نفسي فاغفرلي.json', 'كي نلتقي .json', 'فائقة.json', 'فيصل.json', 'افحسبتم أنما خلقناكم عبثا وأنكم الينا لا ترجعون.json', 'ينس.json', 'طهورة.json', 'إن الله كان توابا رحيما.json', 'مازن.json', 'وماتوفيقي إلا بالله.json', ' والله غالب على أمره.json', 'وخالق الناس بخلق حسن.json', 'تنزيله.json', 'هذا من فضل ربي.json', 'مهرة.json', 'عبد الله.json', 'انما اشكو بثي وحزني الى الله.json', 'ديانا.json', 'المثنى.json', 'ذاناي.json', 'عشق.json', 'والله يعلم وأنتم لا تعلمون.json', 'يا رسول الله.json', 'عهد.json', 'فرزانة.json', 'ولدار الآخرة خير ولنعم دار المتقين.json', 'عبد الرشيد.json', 'وما ارسلناك إلا رحمة للعالمين.json', 'لئن شكرتم لازيدنكم.json', 'غادة الدالي.json', 'رحيمة.json', 'احمد.json', 'أنجل.json', 'المؤمن لا يكذب.json', 'ألا بذكر الله تطمئن القلوب.json', 'غوبي.json', 'إن الله جميل يحب الجمال.json', 'الحمد لله.json', 'الله جل جلاله.json', 'الله في عون العبد مادام العبد في عون اخيه.json', 'عام الخط العربي.json', 'رب نجني من القوم الظالمين.json', 'عي.json', 'وا.json', 'لا اشجار تموت واقفة.json', 'لا تحزن ان الله معنا.json', ' لا اله الا الله محمد رسول الله.json', 'عبد الرحمن.json', 'عامر.json', 'سلام.json', 'وسعت رحمتي كل شيء.json', 'ماشاء الله.json', 'رجب.json', 'مانموهان.json', 'عائلة.json', 'عند قرباني.json', 'ايان.json', 'عيد أضحى مبارك.json ...
# بسم الله الرحمن الرحيم_0.json
# ['وكلهم اتيه يوم القيامة فردا.json', 'لا اله الا الله محمد رسول الله.json', 'خريستوس.json', 'سنا.json', 'لا تيأسوا من روح الله.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'كل عام وأنتم بخير.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'الجزيرة.json', 'دومه.json', 'اشهد ان لا آله الا الله واشهد ان محمد عبده ورسوله.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'برديس.json', 'وهو على كل شيء قدير.json', 'ولا تحسبن الله غافلا عما يعمل الظالمون.json', 'أني مسني الشيطن بنصب وعذاب.json', 'عيد مبارك.json', 'هولي.json', 'ومن يتق الله يجعل له مخرجا ويرزقه من حيث لا يحتسب.json', 'جاكوب.json', 'دومينيك.json', 'ياسمين.json', 'كلماتنا في الحب تقتل حبنا.json', 'وقال ربكم ادعوني استجب لكم.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'رب إني لما أنزلت إلي من خير فقير.json', 'لا يدخل الجنة قاطع رحم.json', 'نيشا.json', 'كنزي.json', 'عذبة.json', 'علية.json', 'شرق الرياض.json', 'ايريك.json', 'الحكم.json', 'رب اشرح لي صدري ويسر لي امري.json', 'عبد المنعم.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'وإني لغفار لمن تاب وأمن وعمل صالحا ثم اهتدى.json', 'سبحان الله.json', 'لا يصدعون عنها ولا ينزفون.json', 'أمينة.json', 'عزام.json', 'عليه توكلت وإليه أنيب.json', 'هني.json', 'عنان.json', 'محمد خير من يمشي على قدم.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'ميثاء.json', 'الله.json', 'عيد كم مبارك.json', 'فطيم.json', 'وسارعوا إلى مغفرة من ربكم.json', 'إقرأ كتابك كفى بنفسك اليوم عليك حسيبا.json', 'ق و القرآن المجيد.json', 'القناعة كنز لا يفنى.json', 'عامر الخط العربي.json', 'انا فتحنا لك فتحا مبينا.json', 'زهرة العراق.json', 'قل هو الله احد.json', 'عصام.json', 'كانديلا.json', 'فسيكفيكهم الله وهو السميع العليم.json', ' يسبح لله ما في السموات وما فى الأرض.json', 'رمضان مبارك.json', 'واعتصموا.json', 'الحلم.json', 'لوكا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'ديفد.json', 'الخط يبقى زمانا بعد كاتبه و كاتب الخط تحت الأرض مدفون.json', 'شيماء.json', 'ولسوف يعطيك ربك فترضى.json', 'أنا لست لي.json', 'الله يثبت.json', 'باتريشا.json', 'ان الله لغني عن العالمين.json', 'سمر.json', 'فرح.json', 'لا إله إلا الله محمد رسول الله.json', 'صباح الخير.json', 'ووو.json', 'طوني.json', 'راجية.json', 'غويلم.json', 'كارولينا.json', 'الحلم سيد الأخلاق.json', 'تاهل.json', 'النجاة في الصدق.json', 'ان في الخيال حياة.json', 'علي رضي الله عنه.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'أليسا.json', 'و لكن الله الف بينهم.json', 'إيمان.json', 'خالد.json', 'الحق.json', 'جلوريا.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'وكان فضل الله عليك عظيما.json', 'اليس الله بكاف عبده.json', 'إن الله مع الذين اتقوا والذين هم محسنون.json', 'كن فيكون.json', 'ولا تهنو ولا تحزنوا وأنتم الأعلون إن كنتم مؤمنين.json', 'اليس الله بأحكم الحاكمين.json', 'الحمد لله رب العالمين.json', 'هل جزاء الإحسان الا الإحسان فبأى آلاء ربكما تكذبان.json', 'واذا مرضت فهو يشفين.json', 'وعد الله الذين آمنوا وعملوا الصالحات لهم مغفرة واجر عظيم.json', 'رب إني ظلمت نفسي فاغفرلي.json', 'كي نلتقي .json', 'فائقة.json', 'فيصل.json', 'القس.json', 'افحسبتم أنما خلقناكم عبثا وأنكم الينا لا ترجعون.json', 'ينس.json', 'طهورة.json', 'إن الله كان توابا رحيما.json', 'مازن.json', 'وماتوفيقي إلا بالله.json', ' والله غالب على أمره.json', 'وخالق الناس بخلق حسن.json', 'تنزيله.json', 'هل يستوي الذين يعلمون والذين لا يعلمون.json', 'نصر من الله وفتح قريب.json', 'هذا من فضل ربي.json', 'مهرة.json', 'عبد الله.json', 'انما اشكو بثي وحزني الى الله.json', 'ديانا.json', 'المثنى.json', 'ذاناي.json', 'عشق.json', 'والله يعلم وأنتم لا تعلمون.json', 'يا رسول الله.json', 'عهد.json', 'فرزانة.json', 'ولدار الآخرة خير ولنعم دار المتقين.json', 'عبد الرشيد.json', 'وما ارسلناك إلا رحمة للعالمين.json', 'لئن شكرتم لازيدنكم.json', 'خليفة.json', 'غادة الدالي.json', 'رحيمة.json', 'احمد.json', 'أنجل.json', 'المؤمن لا يكذب.json', 'ألا بذكر الله تطمئن القلوب.json', 'غوبي.json', 'إن الله جميل يحب الجمال.json', 'الحمد لله.json', 'الله جل جلاله.json', 'الله في عون العبد مادام العبد ...
# بسم الله الرحمن الرحيم_0.json
# ['وكلهم اتيه يوم القيامة فردا.json', 'لا اله الا الله محمد رسول الله.json', 'خريستوس.json', 'سنا.json', 'لا تيأسوا من روح الله.json', 'وما توفيقي الا بالله.json', 'نور على نور.json', 'كل عام وأنتم بخير.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'الجزيرة.json', 'دومه.json', 'اشهد ان لا آله الا الله واشهد ان محمد عبده ورسوله.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'برديس.json', 'وهو على كل شيء قدير.json', 'ولا تحسبن الله غافلا عما يعمل الظالمون.json', 'أني مسني الشيطن بنصب وعذاب.json', 'عيد مبارك.json', 'هولي.json', 'ومن يتق الله يجعل له مخرجا ويرزقه من حيث لا يحتسب.json', 'جاكوب.json', 'دومينيك.json', 'ياسمين.json', 'كلماتنا في الحب تقتل حبنا.json', 'وقال ربكم ادعوني استجب لكم.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'رب إني لما أنزلت إلي من خير فقير.json', 'لا يدخل الجنة قاطع رحم.json', 'نيشا.json', 'كنزي.json', 'عذبة.json', 'علية.json', 'شرق الرياض.json', 'ايريك.json', 'الحكم.json', 'رب اشرح لي صدري ويسر لي امري.json', 'عبد المنعم.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'وإني لغفار لمن تاب وأمن وعمل صالحا ثم اهتدى.json', 'سبحان الله.json', 'الفتاح.json', 'لا يصدعون عنها ولا ينزفون.json', 'أمينة.json', 'عزام.json', 'عليه توكلت وإليه أنيب.json', 'هني.json', 'عنان.json', 'محمد خير من يمشي على قدم.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'ميثاء.json', 'الله.json', 'عيد كم مبارك.json', 'فطيم.json', 'وسارعوا إلى مغفرة من ربكم.json', 'إقرأ كتابك كفى بنفسك اليوم عليك حسيبا.json', 'ق و القرآن المجيد.json', 'القناعة كنز لا يفنى.json', 'عامر الخط العربي.json', 'انا فتحنا لك فتحا مبينا.json', 'زهرة العراق.json', 'قل هو الله احد.json', 'عصام.json', 'كانديلا.json', 'فسيكفيكهم الله وهو السميع العليم.json', ' يسبح لله ما في السموات وما فى الأرض.json', 'محمد صلى الله عليه وسلم.json', 'رمضان مبارك.json', 'واعتصموا.json', 'الحلم.json', 'لوكا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'ديفد.json', 'الخط يبقى زمانا بعد كاتبه و كاتب الخط تحت الأرض مدفون.json', 'شيماء.json', 'ولسوف يعطيك ربك فترضى.json', 'أنا لست لي.json', 'الله يثبت.json', 'باتريشا.json', 'ان الله لغني عن العالمين.json', 'سمر.json', 'فرح.json', 'لا إله إلا الله محمد رسول الله.json', 'صباح الخير.json', 'ووو.json', 'طوني.json', 'راجية.json', 'غويلم.json', 'كارولينا.json', 'الحلم سيد الأخلاق.json', 'تاهل.json', 'النجاة في الصدق.json', 'ان في الخيال حياة.json', 'علي رضي الله عنه.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'أليسا.json', 'و لكن الله الف بينهم.json', 'إيمان.json', 'خالد.json', 'الحق.json', 'جلوريا.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'وكان فضل الله عليك عظيما.json', 'اليس الله بكاف عبده.json', 'إن الله مع الذين اتقوا والذين هم محسنون.json', 'كن فيكون.json', 'ولا تهنو ولا تحزنوا وأنتم الأعلون إن كنتم مؤمنين.json', 'اليس الله بأحكم الحاكمين.json', 'الحمد لله رب العالمين.json', 'هل جزاء الإحسان الا الإحسان فبأى آلاء ربكما تكذبان.json', 'واذا مرضت فهو يشفين.json', 'وعد الله الذين آمنوا وعملوا الصالحات لهم مغفرة واجر عظيم.json', 'رب إني ظلمت نفسي فاغفرلي.json', 'كي نلتقي .json', 'فائقة.json', 'فيصل.json', 'القس.json', 'افحسبتم أنما خلقناكم عبثا وأنكم الينا لا ترجعون.json', 'ينس.json', 'طهورة.json', 'إن الله كان توابا رحيما.json', 'مازن.json', 'وماتوفيقي إلا بالله.json', ' والله غالب على أمره.json', 'وخالق الناس بخلق حسن.json', 'تنزيله.json', 'هل يستوي الذين يعلمون والذين لا يعلمون.json', 'نصر من الله وفتح قريب.json', 'هذا من فضل ربي.json', 'مهرة.json', 'عبد الله.json', 'انما اشكو بثي وحزني الى الله.json', 'ديانا.json', 'المثنى.json', 'ذاناي.json', 'عشق.json', 'والله يعلم وأنتم لا تعلمون.json', 'يا رسول الله.json', 'عهد.json', 'فرزانة.json', 'ولدار الآخرة خير ولنعم دار المتقين.json', 'عبد الرشيد.json', 'وما ارسلناك إلا رحمة للعالمين.json', 'لئن شكرتم لازيدنكم.json', 'خليفة.json', 'غادة الدالي.json', 'رحيمة.json', 'احمد.json', 'أنجل.json', 'المؤمن لا يكذب.json', 'ألا بذكر الله تطمئن القلوب.json', 'غوبي.json', 'إن الله جميل يحب الجمال.json', 'الحمد لله.json', 'الله ...
# بسم الله الرحمن الرحيم _0.json
# ['وكلهم اتيه يوم القيامة فردا.json', 'خير الناس أنفعهم للناس.json', 'لا اله الا الله محمد رسول الله.json', 'خريستوس.json', 'سنا.json', 'لا تيأسوا من روح الله.json', 'وما توفيقي الا بالله.json', 'الإسراء والمعراج.json', 'نور على نور.json', 'كل عام وأنتم بخير.json', 'محمد.json', 'ياروسلاڤ.json', 'لا يكلف الله نفسا إلا وسعها.json', 'الجزيرة.json', 'دومه.json', 'اشهد ان لا آله الا الله واشهد ان محمد عبده ورسوله.json', 'فإذا لقيتم الذين كفروا فضرب الرقاب.json', 'برديس.json', 'وهو على كل شيء قدير.json', 'ولا تحسبن الله غافلا عما يعمل الظالمون.json', 'علي.json', 'أني مسني الشيطن بنصب وعذاب.json', 'عيد مبارك.json', 'هولي.json', 'ومن يتق الله يجعل له مخرجا ويرزقه من حيث لا يحتسب.json', 'جاكوب.json', 'دومينيك.json', 'ياسمين.json', 'كلماتنا في الحب تقتل حبنا.json', 'وقال ربكم ادعوني استجب لكم.json', 'ان الله هو الرزاق ذو القوة المتين.json', 'زاهرة.json', 'رب إني لما أنزلت إلي من خير فقير.json', 'لا يدخل الجنة قاطع رحم.json', 'زبيدة.json', 'نيشا.json', 'نيلي.json', 'كنزي.json', 'عذبة.json', 'علية.json', 'هلا.json', 'شرق الرياض.json', 'سلطان.json', 'ايريك.json', 'الحكم.json', 'رب اشرح لي صدري ويسر لي امري.json', 'عبد المنعم.json', 'الصلاة والسلام عليك ياسيدي يارسول الله.json', 'الاسماء الشخصية.json', 'ارمان.json', 'بسم الله الرحمن الرحيم.json', 'وإني لغفار لمن تاب وأمن وعمل صالحا ثم اهتدى.json', 'سبحان الله.json', 'الفتاح.json', 'أنا اللى بكرا هبقى.json', 'علو الهمة من الإيمان.json', 'لا يصدعون عنها ولا ينزفون.json', 'أمينة.json', 'عزام.json', 'عليه توكلت وإليه أنيب.json', 'هني.json', 'عنان.json', 'محمد خير من يمشي على قدم.json', 'ورحمتي وسعت كل شيء.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'ميثاء.json', 'الله.json', 'عيد كم مبارك.json', 'إنا فتحنا لك فتحا مبينا.json', 'فطيم.json', 'وسارعوا إلى مغفرة من ربكم.json', 'إقرأ كتابك كفى بنفسك اليوم عليك حسيبا.json', 'ق و القرآن المجيد.json', 'القناعة كنز لا يفنى.json', 'عامر الخط العربي.json', 'انا فتحنا لك فتحا مبينا.json', 'زهرة العراق.json', 'قل هو الله احد.json', 'عصام.json', 'كانديلا.json', 'فسيكفيكهم الله وهو السميع العليم.json', ' يسبح لله ما في السموات وما فى الأرض.json', 'محمد صلى الله عليه وسلم.json', 'إنيا.json', 'رمضان مبارك.json', 'واعتصموا.json', 'الحلم.json', 'لوكا.json', 'يجيب المضطر إذا دعاه.json', 'واعتصموا بحبل الله جميعا ولا تفرقوا.json', 'إن الله وإنا إليه لراجعون.json', 'ديفد.json', 'الخط يبقى زمانا بعد كاتبه و كاتب الخط تحت الأرض مدفون.json', 'شيماء.json', 'ولسوف يعطيك ربك فترضى.json', 'ولا هم يحزنون.json', 'أنا لست لي.json', 'روبين.json', 'الله يثبت.json', 'باتريشا.json', 'ان الله لغني عن العالمين.json', 'سمر.json', 'رب لا تذرني فردا و انت خير الوارثين.json', 'فرح.json', 'لا إله إلا الله محمد رسول الله.json', 'صباح الخير.json', 'ووو.json', 'طوني.json', 'راجية.json', 'غويلم.json', 'كارولينا.json', 'فراس.json', 'الحلم سيد الأخلاق.json', 'تاهل.json', 'النجاة في الصدق.json', 'ان في الخيال حياة.json', 'علي رضي الله عنه.json', 'فهد.json', 'عرفان.json', 'انا انزلناه في ليلة القدر.json', 'أليسا.json', 'ولا تدع مع الله إلاها أخر.json', 'و لكن الله الف بينهم.json', 'إيمان.json', 'خالد.json', 'الحق.json', 'جلوريا.json', 'الدين النصيحة.json', 'لا حول ولا قوة إلا بالله العلي العظيم.json', 'سفيان.json', 'دينا.json', 'وكان فضل الله عليك عظيما.json', 'اليس الله بكاف عبده.json', 'إن الله مع الذين اتقوا والذين هم محسنون.json', 'كن فيكون.json', 'ولا تهنو ولا تحزنوا وأنتم الأعلون إن كنتم مؤمنين.json', 'اليس الله بأحكم الحاكمين.json', 'الحمد لله رب العالمين.json', 'هل جزاء الإحسان الا الإحسان فبأى آلاء ربكما تكذبان.json', 'واذا مرضت فهو يشفين.json', 'عيسى.json', 'و لعل ما ترجوه سوف يكون.json', 'وعد الله الذين آمنوا وعملوا الصالحات لهم مغفرة واجر عظيم.json', 'سامر.json', 'رب إني ظلمت نفسي فاغفرلي.json', 'كي نلتقي .json', 'فائقة.json', 'فيصل.json', 'القس.json', 'مايشا.json', 'افحسبتم أنما خلقناكم عبثا وأنكم الينا لا ترجعون.json', 'ينس.json', 'طهورة.json', 'إن الله كان توابا رحيما.json', 'مازن.json', 'وماتوفيقي إلا بالله.json', ' والله غالب على أمره.json', 'وخالق الناس بخلق حسن.json', 'تنزيله.json', 'هيڤن.json', 'ما شاء الله لا قوة الا بالله.json', 'هل يستوي الذين يعلمون والذين لا يعلم ...
# بسم الله الرحمن الرحيم_0.json
# ...
# بسم الله الرحمن الرحيم_0.json
# ['خير الناس أنفعهم للناس.json', 'رالة.json', 'لن تنالوا البر حتى تنفقوا مما تحبون.json', 'نور على نور.json', 'فاصفح الصفح الجميل.json', 'جانسيس.json', 'محمد.json', 'سبحان الله وبحمده سبحان الله العظيم.json', 'رافع.json', 'تبارك.json', 'توقفوا.json', 'سمير.json', 'واعبد ربك حتى ياتيك اليقين.json', 'وقال ربكم ادعوني استجب لكم.json', 'قطر ستبقى حرة تسمو بروح الأوفياء.json', 'بسم الله الرحمن الرحيم.json', 'سبحان الله.json', 'سلام قولا من رب رحيم.json', 'رافائيل.json', 'خيركم من تعلم القران و علمه.json', 'شاذية.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'لئن شكرتم لأزيدنكم.json', 'تعلم الخط العربي.json', 'محمد صلى الله عليه وسلم.json', 'اليساندرا.json', 'كاتارينا.json', 'الريم.json', 'قل أعوذ برب الفلق.json', 'جليلة.json', 'وإن تعدوا نعمة الله لا تحصوها.json', 'بيريڤان.json', 'عبد النور.json', 'لا إله إلا الله محمد رسول الله.json', 'مالك الملك.json', 'اسمع ثم ابتسم ثم تجاهل.json', 'ليتنا كالأسماء لا يغيرنا الزمان.json', 'وإنك لعلى خلق عظيم.json', 'كارا.json', 'وماتوفيقي الا بالله.json', 'قل كل يعمل على شاكلته.json', 'غافر.json', 'ان الحسنات يذهبن السيئات.json', 'نائلة.json', 'عاطف.json', 'ومن يتق الله يجعل له مخرجا و يرزقه من حيث لا يحتسب.json', 'إن الله كان توابا رحيما.json', 'كاثلين.json', 'وماتوفيقي إلا بالله.json', 'هذا من فضل ربي.json', 'إن ربي رحيم ودود.json', 'رسول.json', 'شهر رمضان المبارك.json', 'وأن ليس للإنسان إلا ماسعى.json', 'نحن لا نستسلم ننتصر او نموت.json', 'رب اجعلني مقيم الصلواة ومن ذريتي.json', 'اعقل الناس اعذرهم للناس.json', 'فرح الكعبة البيت الحرام.json', 'لا تقنطوا من رحمة الله.json', 'هيج.json', 'ويمكرون ويمكر الله والله خير الماكرين.json', 'ايناس.json', 'الخنساء.json', 'فاظلم كما شئت لا أرجوك مرحمة.json', 'بلال.json', 'عمارة.json', 'لا اله إلا الله.json', 'وقل رب زدني علما.json', 'صوفي.json', 'بيرل.json', 'بيدرو.json', 'فلله الحمد.json', 'أني مسني الضر وانت ارحم الرحمين.json', 'وأن الله قد احاط بكل شيء علما.json', 'رمضان كريم.json', 'سكينة.json', 'حبراير.json', 'عذرا.json', 'وربك الغنى ذو الرحمة.json', 'أحمد.json', 'صلى الله عليه وسلم.json', 'زين.json', 'شينا.json', 'أدعوني استجب لكم.json', 'أنس الجنيدى.json', 'أميني.json', 'خيركم من تعلم القران وعلمه.json', 'عرين.json', 'ذلك تقدير العزيز العليم.json', 'أنجيلا.json', 'أفنان.json', 'دنيا.json', 'عهدي.json', 'ن والقلم و مايسطرون.json', 'الإسراء والمعراج.json', 'ووجدك عائلا فأغنى.json', 'نور على نور.json', 'محمد.json', 'عينا يشرب بها المقربون.json', 'وعلى.json', 'نهاد.json', 'منصور.json', 'زاين مصطفى.json', 'وهو على كل شيء قدير.json', 'كيَّن.json', 'طاهر.json', 'ومن يتق الله يجعل له مخرجا ويرزقه من حيث لا يحتسب.json', 'إن هذا القرآن يهدي للتي هي أقوم.json', 'دانة.json', 'ادعوني استجب لكم.json', 'جاد.json', 'الحياة تبدأ بعد القهوة.json', 'يوسف.json', 'أيمن.json', 'جيسيكا.json', 'فاذكروني أذكركم.json', 'الحب اهتمام.json', 'أسيل.json', 'إرادة.json', 'عيد فطر سعيد.json', 'نصمت.json', 'بسم الله الرحمن الرحيم.json', 'سبحان الله.json', 'الياسمين.json', 'تسنيم.json', 'زنيرة.json', 'حسني.json', 'كيارا.json', 'أحمد العبد.json', 'ورحمتي وسعت كل شيء.json', 'الله.json', 'صديقة.json', 'القناعة كنز لا يفنى.json', 'عامر الخط العربي.json', 'رب اني ظلمت نفسي فاغفرلي.json', 'انا فتحنا لك فتحا مبينا.json', 'و من يتق الله يجعل له مخرجا ويرزقه من حيث لا يحتسب.json', 'ابتسام.json', 'وفوق كل ذي علم عليم.json', 'إيمي.json', 'قل أعوذ برب الفلق.json', 'فارس.json', 'فتعالى الله الملك الحق.json', 'قهوة.json', 'ولسوف يعطيك ربك فترضى.json', 'خط الثلث.json', 'فواز.json', 'قل لن يصيبنا الا ما كتب الله لنا.json', 'واذكر في الكتاب مريم إذ انتبذت من اهلها مكانا شرقيا.json', 'عبدالله.json', 'فريدة.json', 'لين.json', 'رمضان المبارك.json', 'محبة.json', 'صباح الخير.json', 'ان الله مع الصابرين.json', 'الحلم سيد الأخلاق.json', 'رجاء.json', 'جيهان.json', 'هل جزاء الإحسان إلا الإحسان فبأي الاء ربكما تكذبان.json', 'أميلا.json', 'أمن يجيب المضطر إذا دعاه.json', 'طارق.json', 'لا قوة الا بالله.json', 'الا بذكر الله تطمئن القلوب.json', 'ولمن خاف مقام ربه جنتان.json', 'خالد.json', 'فيكتوريا.json', 'عبد الحليم.json', 'تحسين.json', 'وما الحب إلا أن تخاف الله فيمن تحب.json', 'سوزان.json', 'بفي.json', 'فف ...
# بسم الله_0.json
# ['خير الناس أنفعهم للناس.json', 'كريستيان.json', 'رالة.json', 'لن تنالوا البر حتى تنفقوا مما تحبون.json', 'نور على نور.json', 'فاصفح الصفح الجميل.json', 'جانسيس.json', 'محمد.json', 'سبحان الله وبحمده سبحان الله العظيم.json', 'رائد عزت.json', 'رافع.json', 'تبارك.json', 'توقفوا.json', 'سمير.json', 'واعبد ربك حتى ياتيك اليقين.json', 'وقال ربكم ادعوني استجب لكم.json', 'قطر ستبقى حرة تسمو بروح الأوفياء.json', 'بسم الله الرحمن الرحيم.json', 'سبحان الله.json', 'سلام قولا من رب رحيم.json', 'رافائيل.json', 'خيركم من تعلم القران و علمه.json', 'شاذية.json', 'كل من عليها فان ويبقى وجه ربك ذو الجلال والاكرام.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'لئن شكرتم لأزيدنكم.json', 'الله.json', 'تعلم الخط العربي.json', 'محمد صلى الله عليه وسلم.json', 'اليساندرا.json', 'كاتارينا.json', 'الريم.json', 'قل أعوذ برب الفلق.json', 'جليلة.json', 'وإن تعدوا نعمة الله لا تحصوها.json', 'بيريڤان.json', 'عبد النور.json', 'لا إله إلا الله محمد رسول الله.json', 'مالك الملك.json', 'اسمع ثم ابتسم ثم تجاهل.json', 'ليتنا كالأسماء لا يغيرنا الزمان.json', 'وإنك لعلى خلق عظيم.json', 'كارا.json', 'خالد.json', 'وماتوفيقي الا بالله.json', 'قل كل يعمل على شاكلته.json', 'ملأى السنابل تنحني بتواضع و الفارغات رؤسهن شوامخ.json', 'غافر.json', 'الحمد لله رب العالمين.json', 'ان الحسنات يذهبن السيئات.json', 'نائلة.json', 'عاطف.json', 'ومن يتق الله يجعل له مخرجا و يرزقه من حيث لا يحتسب.json', 'إن الله كان توابا رحيما.json', 'كاثلين.json', 'براك.json', 'وماتوفيقي إلا بالله.json', 'هذا من فضل ربي.json', 'خلق السماوات والارض بالحق تعالى عما يشركون.json', 'إن ربي رحيم ودود.json', 'رسول.json', 'شهر رمضان المبارك.json', 'وأن ليس للإنسان إلا ماسعى.json', 'نحن لا نستسلم ننتصر او نموت.json', 'الله جل جلاله.json', 'رب اجعلني مقيم الصلواة ومن ذريتي.json', 'اعقل الناس اعذرهم للناس.json', 'و اذا مرضت فهو يشفين.json', 'فرح الكعبة البيت الحرام.json', 'حازم.json', 'لا تقنطوا من رحمة الله.json', 'محمد رسول الله.json', 'جاشيم.json', 'هيج.json', 'ويمكرون ويمكر الله والله خير الماكرين.json', 'ايناس.json', 'الخنساء.json', 'فاظلم كما شئت لا أرجوك مرحمة.json', 'بلال.json', 'جاكوبو.json', 'عمارة.json', 'لا اله إلا الله.json', 'وقل رب زدني علما.json', 'صوفي.json', 'بيرل.json', 'بيدرو.json', 'فلله الحمد.json', 'أني مسني الضر وانت ارحم الرحمين.json', 'وأن الله قد احاط بكل شيء علما.json', 'رمضان كريم.json', 'سكينة.json', 'حبراير.json', 'عذرا.json', 'وربك الغنى ذو الرحمة.json', 'أحمد.json', 'ثغر عسقلان.json', 'صلى الله عليه وسلم.json', 'زين.json', 'عمر.json', 'شينا.json', 'أدعوني استجب لكم.json', 'أنس الجنيدى.json', 'أميني.json', 'خيركم من تعلم القران وعلمه.json', 'عرين.json', 'ذلك تقدير العزيز العليم.json', 'أنجيلا.json', 'أفنان.json', 'دنيا.json', 'عهدي.json', 'ن والقلم و مايسطرون.json', 'الإسراء والمعراج.json', 'ووجدك عائلا فأغنى.json', 'نور على نور.json', 'محمد.json', 'عينا يشرب بها المقربون.json', 'وعلى.json', 'نهاد.json', 'منصور.json', 'زاين مصطفى.json', 'وهو على كل شيء قدير.json', 'كيَّن.json', 'طاهر.json', 'ومن يتق الله يجعل له مخرجا ويرزقه من حيث لا يحتسب.json', 'إن هذا القرآن يهدي للتي هي أقوم.json', 'دانة.json', 'ادعوني استجب لكم.json', 'جاد.json', 'الحياة تبدأ بعد القهوة.json', 'يوسف.json', 'أيمن.json', 'جيسيكا.json', 'فاذكروني أذكركم.json', 'الحب اهتمام.json', 'أسيل.json', 'إرادة.json', 'عيد فطر سعيد.json', 'نصمت.json', 'بسم الله الرحمن الرحيم.json', 'سبحان الله.json', 'الياسمين.json', 'تسنيم.json', 'زنيرة.json', 'حسني.json', 'كيارا.json', 'أحمد العبد.json', 'ورحمتي وسعت كل شيء.json', 'الله.json', 'صديقة.json', 'القناعة كنز لا يفنى.json', 'عامر الخط العربي.json', 'رب اني ظلمت نفسي فاغفرلي.json', 'انا فتحنا لك فتحا مبينا.json', 'و من يتق الله يجعل له مخرجا ويرزقه من حيث لا يحتسب.json', 'ابتسام.json', 'وفوق كل ذي علم عليم.json', 'إيمي.json', 'قل أعوذ برب الفلق.json', 'فارس.json', 'فتعالى الله الملك الحق.json', 'قهوة.json', 'ولسوف يعطيك ربك فترضى.json', 'خط الثلث.json', 'فواز.json', 'قل لن يصيبنا الا ما كتب الله لنا.json', 'واذكر في الكتاب مريم إذ انتبذت من اهلها مكانا شرقيا.json', 'عبدالله.json', 'فريدة.json', 'لين.json', 'رمضان المبارك.json', 'محبة.json', 'صباح الخير.json', 'ان الله مع  ...
# بسم الله الرحمن الرحيم_0.json
# ['مهناز.json', 'خير الناس أنفعهم للناس.json', 'ليلة القدر خير من ألف شهر.json', 'لا اله الا الله محمد رسول الله.json', 'كريستيان.json', 'رالة.json', 'الم نشرح لك صدرك.json', 'لن تنالوا البر حتى تنفقوا مما تحبون.json', 'فإنها لا تعمى الأبصار ولكن تعمى القلوب التي في الصدور.json', 'مها.json', 'نور على نور.json', 'فاصفح الصفح الجميل.json', 'جانسيس.json', 'محمد.json', 'سبحان الله وبحمده سبحان الله العظيم.json', 'رائد عزت.json', 'رافع.json', 'تبارك.json', 'بيدك الخير.json', 'أمير.json', 'عيد مبارك.json', 'توقفوا.json', 'سمير.json', 'واعبد ربك حتى ياتيك اليقين.json', 'وقال ربكم ادعوني استجب لكم.json', 'شون.json', 'يارب.json', 'صفاء.json', 'نيلي.json', 'ليس كمثله شيء.json', 'قطر ستبقى حرة تسمو بروح الأوفياء.json', 'ما شاء الله.json', 'بسم الله الرحمن الرحيم.json', 'سبحان الله.json', 'سلام قولا من رب رحيم.json', 'رغد.json', 'رافائيل.json', 'خيركم من تعلم القران و علمه.json', 'شاذية.json', 'كل من عليها فان ويبقى وجه ربك ذو الجلال والاكرام.json', 'م.json', 'فتوكل على الله إن الله يحب المتوكلين.json', 'لئن شكرتم لأزيدنكم.json', 'الله.json', 'هو الخلاق الباقي.json', 'حسبي الله.json', 'تعلم الخط العربي.json', 'أنت ما تحب.json', 'محمد صلى الله عليه وسلم.json', 'رمضان مبارك.json', 'وان تعدوا نعمة الله لا تحصوها ان الله غفور رحيم.json', 'اليساندرا.json', 'كاتارينا.json', 'الريم.json', 'قل أعوذ برب الفلق.json', 'جليلة.json', 'وإن تعدوا نعمة الله لا تحصوها.json', 'بيريڤان.json', 'عيد فطر مبارك.json', 'سعد.json', 'أسامة.json', 'عبدالله.json', 'عبد النور.json', 'لا إله إلا الله محمد رسول الله.json', 'مالك الملك.json', 'اسمع ثم ابتسم ثم تجاهل.json', 'توكلت على الله.json', 'و ما تفعلوا من خير فان الله به عليم.json', 'ليتنا كالأسماء لا يغيرنا الزمان.json', 'ياودود.json', 'وإنك لعلى خلق عظيم.json', 'أنتينينا.json', 'كارا.json', 'شهر رمضان الذي أنزل فيه القرآن.json', 'خالد.json', 'ربنا أفرغ علينا صبرا وتوفنا مسلمين.json', 'وماتوفيقي الا بالله.json', 'قل كل يعمل على شاكلته.json', 'درغام.json', 'ليا.json', 'أرض البركة.json', 'ملأى السنابل تنحني بتواضع و الفارغات رؤسهن شوامخ.json', 'آدم.json', 'كن فيكون.json', 'غافر.json', 'الحمد لله رب العالمين.json', 'إن الحكم إلا لله.json', 'نوفي.json', 'فاذا عزمت فتوكل على الله.json', 'القرآن الكريم.json', 'ان الحسنات يذهبن السيئات.json', 'نائلة.json', 'الحلم سيد الاخلاق.json', 'عاطف.json', 'الجود.json', 'ومن يتق الله يجعل له مخرجا و يرزقه من حيث لا يحتسب.json', 'وإن من شيء إلا يسبح بحمده.json', 'إن الله كان توابا رحيما.json', 'كاثلين.json', 'شام.json', 'للذين احسنوا الحسنى وزيادة.json', 'براك.json', 'وماتوفيقي إلا بالله.json', 'هذا من فضل ربي.json', 'خلق السماوات والارض بالحق تعالى عما يشركون.json', 'إن ربي رحيم ودود.json', 'إليزابيث.json', 'رسول.json', 'حواء.json', 'شهر رمضان المبارك.json', 'لا حول ولا قوة إلى بالله.json', 'شريف.json', 'وأن ليس للإنسان إلا ماسعى.json', 'إن هذا القران يهدي للتي هي أقوم.json', 'لئن شكرتم لازيدنكم.json', 'نحن لا نستسلم ننتصر او نموت.json', 'دييجو.json', 'لا اله الا الله.json', 'إسراء.json', 'الحمد لله.json', 'الله جل جلاله.json', 'شريعة.json', 'رب اجعلني مقيم الصلواة ومن ذريتي.json', 'اعقل الناس اعذرهم للناس.json', 'واحسن كما احسن الله اليك.json', 'رفيق.json', 'و اذا مرضت فهو يشفين.json', 'ماشاء الله.json', 'فرح الكعبة البيت الحرام.json', 'حازم.json', 'لا تقنطوا من رحمة الله.json', 'وأما بنعمة ربك فحدث.json', 'محمد رسول الله.json', 'احد صمد.json', 'جاشيم.json', 'هيج.json', 'أنا عند ظن عبدي بي و أنا معه حيث يذكرني.json', 'انه سميع الدعاء.json', 'ويمكرون ويمكر الله والله خير الماكرين.json', 'الله اكبر.json', 'ايناس.json', 'مشنوي.json', 'استغفروا ربكم.json', 'الخنساء.json', 'فاظلم كما شئت لا أرجوك مرحمة.json', 'بلال.json', 'خير أيامكم يوم الجمعة.json', 'الزين.json', 'رب اغفر لي ولوالدي.json', 'خالدة.json', 'جاكوبو.json', 'عمارة.json', 'قل اعوذ برب الفلق.json', 'لا اله إلا الله.json', 'وقل رب زدني علما.json', 'فإن الجنة هي المأوى.json', 'غفرانك يا رب.json', 'عهد البحار السبع.json', 'صوفي.json', 'بيرل.json', 'وأذكر ربك إذا نسيت.json', 'بيدرو.json', 'علي رضى الله عنه.json', 'ولا تنسوا الفضل بينكم.json', 'لا حول ولا قوة إلا بالله.json', 'كلمات.json', 'إحسان.json', 'فلله الحمد.json', 'المسلم  ...

# %%
len(glob.glob('dataset/**/**.json'))
# Out:
# 1780

# %%
def apply_rdb(drawing, verbose = 0):
    new_drawing = []
    total_prev_strokes = 0
    total_post_strokes = 0
    for item in drawing:
        char = list(item.keys())[0]
        stroke = item[char]
        processed_stroke = []
        if len(stroke):
            if verbose:
                print('processing ', char)
            post_stroke = rdp(stroke, epsilon = 2.0)
            total_post_strokes += len(post_stroke)
            total_prev_strokes += len(stroke)
        new_drawing.append({char:post_stroke})
    if verbose:
        print('reduced from ', total_prev_strokes, ' to ', total_post_strokes)
    return new_drawing

# %%
#https:#jrgraphix.net/r/Unicode/0600-06FF
map_chars = {
    "\u0623":["\u0621", "\u0627"], # أ
    "\u0622":["\u0605", "\u0627"], # آ
    "\u0625":["\u0627", "\u0621"], # إ
    "\u0628":["\u066E", "."], # ب
    "\u062A":[".", ".", "\u066E"], # ت
    "\u062B":[".", ".", ".", "\u066E"], # ث 
    "\u062C":["\u062D", "."], # ج
    "\u062E":[".", "\u062D"], # خ
    "\u0630":[".", "\u062F"], # ذ
    "\u0632":[".", "\u0631"], # ز
    "\u0634":[".", ".", ".", "\u0633"], # ش
    "\u0636":[".", "\u0635"], # ض
    "\u0637":["\u0627", "\uFEBB"], # ط
    "\u0638":[".", "\u0627", "\uFEBB"], # ظ
    "\u063A":[".", "\u0639"], # غ
    "\u0641":[".", "\u066F"], # ف
    "\u0642":[".", ".", "\u066F"], # ق
    "\u06A4":[".", ".", ".", "\u066F"], # ڤ
    "\u0643":["\u0621", "\u0644"], # ك
    "\u0646":[".", "\u06BA"], # ن
    "\u0624":["\u0621", "\u0648"], # ؤ
    "\u064A":["\u0649", ".", "."], #ي
    "\u0626":["\u0621", "\u0649"], #ئ
    "\u0629":[".", ".", "\u0647"], #ه
}

# %%
def preprocess(text):
    char_comps = []
    
    diacritics = "[ًٌٍَُِّْ]"
    numbers = '0123456789'
    for diac in diacritics: 
        text = text.replace(diac, '')

    for num in numbers: 
        text = text.replace(num, '')
    
    outText = ""
    
    for i in range(len(text)):
    
        if (text[i] == " "):
            continue
    
        if text[i] in map_chars:
            if (i < len(text) - 1 and text[i] == "\u0643"):
                if text[i+1] != ' ':
                    char_comps.append({text[i] : '\uFEDB'})
                    outText += '\uFEDB'
                else:
                    char_comps.append({text[i] : map_chars[text[i]]})
                    outText += ''.join(map_chars[text[i]])
            else:
                char_comps.append({text[i] : map_chars[text[i]]})
                outText += ''.join(map_chars[text[i]])
        else:
                char_comps.append({text[i] : text[i]})
                outText += text[i]

    return char_comps, outText

# %%
def concatenate(images, mode='h', margin=10):
    widths, heights = zip(*(i.size for i in images))
    if mode =='h':
        total_width = sum(widths)
        max_height = max(heights)

        new_im = Image.new('RGB', (total_width, max_height), (255, 255, 255))

        x_offset = 0
        for im in images[::-1]:
            new_im.paste(im, (x_offset,0))
            x_offset += im.size[0]
    elif mode == 'v':    
        total_height = sum(heights)
        max_width = max(widths)

        new_im = Image.new('RGB', (max_width, total_height+margin*(len(images)-1)), (255, 255, 255))
        draw = ImageDraw.Draw(new_im)
        y_offset = 0
        for im in images:
            new_im.paste(im, (0,y_offset+margin))
            y_offset += im.size[1]
            draw.line((0,y_offset+margin-5, max_width,y_offset+margin-5), fill=(0, 0, 0), width=3)
    return new_im

# %%
def generate_characters(file):
    char_drawings = []
    annot = file.split('/')[-1][:-5]
    char_comps = preprocess(annot)
    drawing = json.load(open(file))
    new_drawing = apply_rdb(drawing, verbose = 0)
    i = 0 
    for comp in char_comps:
        char = list(comp.keys())[0]
        j = i + len(comp[char])
        char_drawings.append({char:new_drawing[i:j]})
        i = j 
    return char_drawings

# %%
import glob
npy_files = glob.glob('server/larger_data/*')
file = np.random.choice(npy_files)

# %%
len(glob.glob('server/larger_data/*'))
# Out:
# 1800

# %%
wrong_annotations = []
for file in glob.glob('server/data/*'):
    drawing = json.load(open(file))
    stroke_chars = ''
    _, original_stroke_chars = preprocess(file.split("/")[-1][:-5].split('_')[-1])
    for comp in drawing:
        stroke_chars += list(comp.keys())[0]
    if stroke_chars != original_stroke_chars:
        print(file)
        print(stroke_chars)
        print(original_stroke_chars)
        wrong_annotations.append(file)
        data1, flag = convert_3d(drawing, return_flag=True, threshold=50)
        plt.imshow(draw_strokes(data1, stroke_width = 5))
        plt.show()

# %%
len(glob.glob('server/larger_data/*') + glob.glob('server/data/*'))
# Out:
# 2417

# %%
len(glob.glob('server/static/processed_larger_images/*') + glob.glob('server/static/images/*'))
# Out:
# 2500

# %%
wrong_annotations = []
for file in glob.glob('server/larger_data/*'):
    drawing = json.load(open(file))
    stroke_chars = ''
    _, original_stroke_chars = preprocess(file.split("/")[-1][:-5])
    for comp in drawing:
        stroke_chars += list(comp.keys())[0]
    if stroke_chars != original_stroke_chars:
        print(file)
        print(stroke_chars)
        print(original_stroke_chars)
        wrong_annotations.append(file)
        data1, flag = convert_3d(drawing, return_flag=True, threshold=50)
        plt.imshow(draw_strokes(data1, stroke_width = 5))
        plt.show()

# %%
wrong_annotations
# Out:
# []

# %%
import os
import shutil

for file in wrong_annotations:
    file_name = file.split('/')[-1][:-5]
    os.remove(file)  
    shutil.move(f'server/static/processed_larger_images/{file_name}.jpg', f'server/static/larger_images/{file_name}.jpg')

# %%
import os
import shutil

for file in wrong_annotations:
    file_name = file.split("/")[-1][:-5]
    new_image_name = file.split("/")[-1][:-5].split('_')[-1]
    try:
        os.remove(file)  
        shutil.move(f'server/static/images/{file_name}.jpg', f'server/static/larger_images/{new_image_name}.jpg')
    except:
        continue

# %%
# !ls server/larger_data/ | wc -l
# Out:
# 1818
